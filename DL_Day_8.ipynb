# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv-Chopade/Deep-Learning/blob/main/DL_Day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import imdb

# %%
(X_train , y_train) , (X_test, y_test) = imdb.load_data(num_words= 1000)

# %%
from typing import Sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
X_train = pad_sequences(X_train, maxlen= 500)
X_test = pad_sequences(X_test, maxlen= 500)

# %% [markdown]
# Build RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
model = Sequential()
model.add(Embedding(input_dim=1000 , output_dim = 32, input_length=500))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])

# %%
history = model.fit(X_train , y_train ,epochs = 5, validation_split = 0.2 ,validation_data = (X_test , y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 119s 150ms/step - accuracy: 0.6473 - loss: 0.6171 - val_accuracy: 0.7453 - val_loss: 0.5228
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 113s 145ms/step - accuracy: 0.6995 - loss: 0.5731 - val_accuracy: 0.6442 - val_loss: 0.6172
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 145s 149ms/step - accuracy: 0.7253 - loss: 0.5474 - val_accuracy: 0.6306 - val_loss: 0.6396
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 117s 149ms/step - accuracy: 0.7231 - loss: 0.5468 - val_accuracy: 0.6648 - val_loss: 0.6035
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 138s 144ms/step - accuracy: 0.7407 - loss: 0.5289 - val_accuracy: 0.7509 - val_loss: 0.5322

# %%
from tensorflow.keras.layers import LSTM , GRU

# %%
model_lstm = Sequential()
model_lstm.add(Embedding(input_dim=1000 , output_dim = 32, input_length=500))
model_lstm.add(LSTM(32))
model_lstm.add(Dense(1, activation='sigmoid'))
model_lstm.compile(optimizer  = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
history_lstm = model_lstm.fit(X_train , y_train , epochs = 5 , validation_split = 0.2 , validation_data = (X_test , y_test))
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 194s 244ms/step - accuracy: 0.7532 - loss: 0.4965 - val_accuracy: 0.8343 - val_loss: 0.4059
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 191s 244ms/step - accuracy: 0.8395 - loss: 0.3646 - val_accuracy: 0.8638 - val_loss: 0.3281
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 249ms/step - accuracy: 0.8579 - loss: 0.3341 - val_accuracy: 0.8664 - val_loss: 0.3150
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 195s 240ms/step - accuracy: 0.8679 - loss: 0.3174 - val_accuracy: 0.8702 - val_loss: 0.3142
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 194s 249ms/step - accuracy: 0.8765 - loss: 0.2982 - val_accuracy: 0.8720 - val_loss: 0.3045

# %%
model_gru = Sequential()
model_gru.add(Embedding(input_dim=1000 , output_dim = 32, input_length=500))
model_gru.add(GRU(32))
model_gru.add(Dense(1, activation='sigmoid'))
model_gru.compile(optimizer  = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
history_gru = model_gru.fit(X_train , y_train , epochs = 5 , validation_split = 0.2 , validation_data = (X_test , y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 265s 335ms/step - accuracy: 0.7398 - loss: 0.5104 - val_accuracy: 0.6947 - val_loss: 0.5823
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 306s 315ms/step - accuracy: 0.8209 - loss: 0.4125 - val_accuracy: 0.8444 - val_loss: 0.3616
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 255s 326ms/step - accuracy: 0.8605 - loss: 0.3351 - val_accuracy: 0.8655 - val_loss: 0.3174
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 254s 315ms/step - accuracy: 0.8746 - loss: 0.3018 - val_accuracy: 0.8697 - val_loss: 0.3076
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 274s 330ms/step - accuracy: 0.8821 - loss: 0.2809 - val_accuracy: 0.8738 - val_loss: 0.2973
