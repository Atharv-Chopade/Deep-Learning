# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv-Chopade/Deep-Learning/blob/main/DL_Day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import imdb

# %%
(X_train, y_train) , (X_test , y_test) = imdb.load_data(num_words=10000)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_train = pad_sequences(X_train,maxlen=200)
X_test = pad_sequences(X_test,maxlen=200)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Flatten,Dense,LSTM

# %%
model = Sequential()
model.add(Embedding(input_dim=10000 , output_dim= 128 , input_length = 200))
model.add(LSTM(64))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])

# %%
history = model.fit(X_train ,y_train , epochs = 5 , validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 98s 153ms/step - accuracy: 0.7872 - loss: 0.4479 - val_accuracy: 0.8658 - val_loss: 0.3253
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 88s 140ms/step - accuracy: 0.8992 - loss: 0.2532 - val_accuracy: 0.8786 - val_loss: 0.3094
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 141s 138ms/step - accuracy: 0.9324 - loss: 0.1766 - val_accuracy: 0.8690 - val_loss: 0.3534
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 137ms/step - accuracy: 0.9510 - loss: 0.1338 - val_accuracy: 0.8558 - val_loss: 0.3655
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 87s 138ms/step - accuracy: 0.9678 - loss: 0.0926 - val_accuracy: 0.8612 - val_loss: 0.4494

# %%
loss , accuracy = model.evaluate(X_test , y_test)
print(accuracy , loss)

# %%
pred = model.predict(X_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
